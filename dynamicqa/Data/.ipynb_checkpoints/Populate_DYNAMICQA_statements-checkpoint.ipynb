# %%
import pandas as pd

# %%
mode = "static"
df_matched = pd.read_csv("Static_extracted_templates.csv")

# %%
df_questions = pd.read_csv("dynamicqa_converted_templates.csv")

# Group by 'question' and aggregate the 'statement' values into lists
question_dict = df_questions.groupby('question')['statement'].apply(list).to_dict()

# %%
# Check: ensure every matched_template exists in question_dict
missing = set(df_matched['matched_template']) - set(question_dict.keys())
if missing:
    raise ValueError(f"❌ The following matched_template(s) are not in question_dict: {missing}")

# %%
# Expand the dataframe
expanded_rows = []

for _, row in df_matched.iterrows():
    question = row['matched_template']
    for i, stmt in enumerate(question_dict[question]):  # i goes from 0 → 4
        new_row = row.copy()

        stmt = stmt.replace("[Y]", "_X_")
        stmt = stmt.replace("[X]", row["subj"])
        new_row['statement'] = stmt

        if mode == "static":
            new_row['mulan_id'] = f"{row['subj_id']}_{row['prop_id']}S_{i}"
        elif mode == "temporal":
            new_row['mulan_id'] = f"{row['subj_id']}_{row['prop_id']}T_{i}"
        expanded_rows.append(new_row)

expanded_df = pd.DataFrame(expanded_rows)

# %%
expanded_df.head()
# Out:
#    Unnamed: 0       id            subj        prop         obj    subj_id  \
# 0          10  1223902  Herlyn Espinal  occupation  journalist  Q17412700
# 0          10  1223902  Herlyn Espinal  occupation  journalist  Q17412700
# 0          10  1223902  Herlyn Espinal  occupation  journalist  Q17412700
# 0          10  1223902  Herlyn Espinal  occupation  journalist  Q17412700
# 0          10  1223902  Herlyn Espinal  occupation  journalist  Q17412700
#
#   prop_id    obj_id  s_pop  o_pop  ... num_edits  \
# 0    P106  Q1930187     88  24952  ...       1.0
# 0    P106  Q1930187     88  24952  ...       1.0
# 0    P106  Q1930187     88  24952  ...       1.0
# 0    P106  Q1930187     88  24952  ...       1.0
# 0    P106  Q1930187     88  24952  ...       1.0
#
#                                              context  replace_quality  \
# 0   Herlyn Iván Espinal Martínez (14 September 19...         0.735473
# 0   Herlyn Iván Espinal Martínez (14 September 19...         0.735473
# 0   Herlyn Iván Espinal Martínez (14 September 19...         0.735473
# 0   Herlyn Iván Espinal Martínez (14 September 19...         0.735473
# 0   Herlyn Iván Espinal Martínez (14 September 19...         0.735473
#
#       replace_name  s_pop_new o_pop_new           matched_template  \
# 0  literary critic       73.0       4.0  What is [X]'s occupation?
# 0  literary critic       73.0       4.0  What is [X]'s occupation?
# 0  literary critic       73.0       4.0  What is [X]'s occupation?
# 0  literary critic       73.0       4.0  What is [X]'s occupation?
# 0  literary critic       73.0       4.0  What is [X]'s occupation?
#
#          extracted_sub                       statement           mulan_id
# 0  ('Herlyn Espinal',)        [X]'s occupation is [Y].  Q17412700_P106S_0
# 0  ('Herlyn Espinal',)  [X] has the occupation of [Y].  Q17412700_P106S_1
# 0  ('Herlyn Espinal',)             [X] works as a [Y].  Q17412700_P106S_2
# 0  ('Herlyn Espinal',)          The job of [X] is [Y].  Q17412700_P106S_3
# 0  ('Herlyn Espinal',)    By occupation, [X] is a [Y].  Q17412700_P106S_4
#
# [5 rows x 22 columns]
