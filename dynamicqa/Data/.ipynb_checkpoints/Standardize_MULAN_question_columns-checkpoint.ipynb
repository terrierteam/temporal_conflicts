# %%
from datasets import load_from_disk, load_dataset
import pandas as pd
import json

# %%
dataset = load_from_disk("MULAN_with_questions")
dataset
# Out:
# Dataset({
#     features: ['query', 'answer', 'id', 'relation', 'date', 'type', 'extracted_subject', 'selected_answer', 'prompt', 'messages', 'context', 'selected_fact', 'question'],
#     num_rows: 49049
# })

# %%
df = dataset.to_pandas()
df.head()
# Out:
#                                             query  \
# 0         Barack Obama works in the field of _X_.
# 1                Jesus works in the field of _X_.
# 2  William Shakespeare works in the field of _X_.
# 3         Adolf Hitler works in the field of _X_.
# 4         Donald Trump works in the field of _X_.
#
#                                               answer             id relation  \
# 0  [{'wikidata_id': 'Q25447176', 'name': 'civil r...     Q76_P101_0     P101
# 1  [{'wikidata_id': 'Q203605', 'name': 'carpentry...    Q302_P101_0     P101
# 2  [{'wikidata_id': 'Q8253972', 'name': 'fiction'...    Q692_P101_0     P101
# 3  [{'wikidata_id': 'Q7310', 'name': 'Nazism'}, {...    Q352_P101_0     P101
# 4  [{'wikidata_id': 'Q10494269', 'name': 'real pr...  Q22686_P101_0     P101
#
#    date         type                                  extracted_subject  \
# 0  2021  immutable_n  {'subject': 'Barack Obama', 'template': '[X] w...
# 1  2021  immutable_n  {'subject': 'Jesus', 'template': '[X] works in...
# 2  2021  immutable_n  {'subject': 'William Shakespeare', 'template':...
# 3  2021  immutable_n  {'subject': 'Adolf Hitler', 'template': '[X] w...
# 4  2021  immutable_n  {'subject': 'Donald Trump', 'template': '[X] w...
#
#                                      selected_answer  \
# 0  {'name': 'constitutional law', 'wikidata_id': ...
# 1    {'name': 'carpentry', 'wikidata_id': 'Q203605'}
# 2     {'name': 'fiction', 'wikidata_id': 'Q8253972'}
# 3  {'name': 'Nazi propaganda', 'wikidata_id': 'Q7...
# 4     {'name': 'government', 'wikidata_id': 'Q7188'}
#
#                                               prompt  \
# 0  \nCreate a small paragraph (3-4 sentences) tha...
# 1  \nCreate a small paragraph (3-4 sentences) tha...
# 2  \nCreate a small paragraph (3-4 sentences) tha...
# 3  \nCreate a small paragraph (3-4 sentences) tha...
# 4  \nCreate a small paragraph (3-4 sentences) tha...
#
#                                             messages  \
# 0  [{'content': 'You are an expert Wikipedia edit...
# 1  [{'content': 'You are an expert Wikipedia edit...
# 2  [{'content': 'You are an expert Wikipedia edit...
# 3  [{'content': 'You are an expert Wikipedia edit...
# 4  [{'content': 'You are an expert Wikipedia edit...
#
#                                              context  \
# 0  Barack Obama is an American politician and att...
# 1  Jesus is believed to have been born in Bethleh...
# 2  William Shakespeare is widely regarded as one ...
# 3  Adolf Hitler was a key figure in the developme...
# 4  Donald Trump is an American businessman, telev...
#
#                                        selected_fact  \
# 0  Barack Obama works in the field of constitutio...
# 1              Jesus works in the field of carpentry
# 2  William Shakespeare works in the field of fiction
# 3  Adolf Hitler works in the field of Nazi propag...
# 4      Donald Trump works in the field of government
#
#                                        question
# 0         What field does Barack Obama work in?
# 1                What field does Jesus work in?
# 2  What field does William Shakespeare work in?
# 3         What field does Adolf Hitler work in?
# 4         What field does Donald Trump work in?

# %%
with open("aliases.json", "r") as f:
    aliases = json.load(f)
len(aliases)
# Out:
# 25179

# %%
def get_subject(example):
    subj = example["extracted_subject"]["subject"]
    example["subj"] = subj
    return example

def get_obj(example):
    obj = example["selected_answer"]["name"]
    example["obj"] = obj
    return example

def get_subj_id(example):
    subj_id = example["id"].split("_")[0]
    example["subj_id"] = subj_id
    return example

def get_obj_id(example):
    obj_id = example["selected_answer"]["wikidata_id"]
    example["obj_id"] = obj_id
    return example

def get_possible_answers(example):
    possible_answers = []
    for ans in example["answer"]:
        possible_answers.append(ans["name"])
        if ans["wikidata_id"] in aliases:
            possible_answers.extend(aliases[ans["wikidata_id"]])
    example["possible_answers"] = possible_answers
    return example
